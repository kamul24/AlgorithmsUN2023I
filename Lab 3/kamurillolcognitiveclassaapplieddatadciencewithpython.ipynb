# %% [markdown]
# **LinkedIn**

# %% [markdown]
#  Link: www.linkedin.com/in/karla-estefania-murillo-lopez-963695222

# %% [markdown]
# ![Certificado 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![c1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![c2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![c4.jpg](data:image/jpeg;base64,...)
